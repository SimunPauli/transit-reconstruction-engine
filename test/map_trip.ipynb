# %%
import folium
import webbrowser
import os

leg_i_geo = df.loc[df['iteration_id']==0, "leg_geometry_length"].copy()

m = folium.Map(location=leg_i_geo.iloc[1][0], zoom_start=12,
               tiles="OpenStreetMap")
# Add polylines
folium.PolyLine(leg_i_geo.iloc[0], color='red').add_to(m)
folium.PolyLine(leg_i_geo.iloc[1], color='blue').add_to(m)
folium.PolyLine(leg_i_geo.iloc[2], color='red').add_to(m)
folium.PolyLine(leg_i_geo.iloc[3], color='green').add_to(m)
folium.PolyLine(leg_i_geo.iloc[4], color='red').add_to(m)

file_path = os.path.expanduser("~/O/TU_Rejseplan/map.html")
m.save(file_path)

# %%
import folium
import webbrowser
import os

leg_i_geo = df_combined.loc[df_combined['iteration_id']==1, "leg_geometry_length"].copy()
m = folium.Map(location=leg_i_geo.iloc[1][0], zoom_start=12,
               tiles="OpenStreetMap")
# Add polylines
folium.PolyLine(leg_i_geo.iloc[0], color='blue').add_to(m)
folium.PolyLine(leg_i_geo.iloc[1], color='red').add_to(m)
folium.PolyLine(leg_i_geo.iloc[2], color='green').add_to(m)

file_path = os.path.expanduser("~/O/TU_Rejseplan/map.html")
m.save(file_path)
